# %%
#2.

# %matplotlib notebook
# %matplotlib notebook  
import matplotlib.pyplot as plt

# years = ['2017', '2018', '2019', '2020', '2021', '2022']

# bears = [8, 54, 93, 116, 137, 184]

# dolphins = [150, 77, 32, 11, 6, 1]

# whales = [80, 54, 100, 76, 93, 72]

file = open('wildlife.txt')
years1 = []
bears1 = []
dolphins1 = []
whales1 = []

next(file)

lines = file.readlines()
for line in lines:
    output = line.split('\t')
#     print(output)
    for i in output:
        if i == '':
            output.remove(i)

    years1.append(int(output[0]))
    bears1.append(int(output[1]))
    dolphins1.append(int(output[2]))
    whales1.append(int(output[3]))

plt.figure(figsize=(5,5))

plt.plot(years, bears1, label = "Bears")

plt.plot(years, dolphins1, label = "Dolphins")

plt.plot(years, whales1, label = "Whales")

plt.xlabel('Years')

plt.ylabel('Wildlife Population')

plt.title('Wildlife Population Per Year')

plt.legend(loc='upper left') 

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
# Out:
# 3.)

# %%
#3.

# %matplotlib notebook
# %matplotlib notebook  
import matplotlib.pyplot as plt 

f = open('cartype.txt', 'r') 
next(f)
content_list = [line.rstrip('\n') for line in f]
#print(content_list)
    
length_of_list = len(content_list)
#print(length_of_list)
    
smallcount = 0
midsizecount = 0
compactcount = 0
largecount = 0
sportycount = 0
vancount = 0
    
    
for i in content_list:
    if i == "small":
        smallcount += 1
    if i == "midsize":
        midsizecount += 1
    if i == "compact":
        compactcount += 1
    if i == "large":
        largecount += 1
    if i == "sporty":
        sportycount += 1
    if i == "van":
        vancount += 1
    
# smallfreq = (smallcount/length_of_list) * 100
# midsizefreq = (midsizecount/length_of_list) * 100
# compactfreq = (compactcount/length_of_list) * 100
# largefreq = (largecount/length_of_list) * 100
# sportyfreq = (sportycount/length_of_list) * 100
# vanfreq = (vancount/length_of_list) * 100
    
cartypes = ['small', 'midsize', 'large', 'compact', 'van', 'sporty']
    
slices = [smallcount , midsizecount, largecount, compactcount, vancount, sportycount]
    
colors = ['purple', 'b', 'gray', 'purple', 'b', 'gray']

plt.pie(slices, labels = cartypes, colors=colors, explode = (0.025,0.025,0.025,0.025,0.025,0.025),
        radius = 1.2, autopct = '%2.2f%%') 


# showing the plot 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#4.

import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(2)  # Create a figure containing a single axes.

years = ['2003', '2004', '2005', '2006', '2007'] 

# y-axis - line 1 data
full_time_students = [10000, 9500, 11100, 12000, 13300] 

# y-axis - line 2 data
part_time_students = [2000, 2100, 2050, 2700, 2550]


ax[0].plot(years, full_time_students, label = 'Enrollment of full-time students') 

ax[0].set_xlabel('Years')
ax[0].set_ylabel('Number of Students Erolled')
ax[0].set_title('Student Enrollment Per Year')
ax[0].legend()


ax[1].plot(years, part_time_students, label = 'Enrollment of part-time students') 

ax[1].set_xlabel('Years')
ax[1].set_ylabel('Number of Students Erolled')
ax[1].set_title('Student Enrollment Per Year')
ax[1].legend()



# ax.subplot(years, part_time_students)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#1.

# %matplotlib notebook
# %matplotlib notebook  
import matplotlib.pyplot as plt 
import math

file = open('carprices.txt')
next(file)

initial = []
lines = file.readlines()

for val in lines:
    try:
        initial.append(int(val))
        
    except ValueError:
        print('This data '+val+' is invalid and will be ignored')
        lines.remove(val)
        
final = []
for val in initial:
    final.append(math.floor(val/10)) 
    
range = (0, 50)
bins = 50

# plotting a histogram 
plt.hist(final, bins, range,color = 'cornflowerblue', histtype = 'bar', rwidth = 0.8) 

# x-axis label 
plt.xlabel('Price in tens of thousands') 

# frequency label 
plt.ylabel('Number of cars') 

# plot title 
plt.title('Frequency of Car Prices') 

# function to show the plot 
plt.show()
# Out:
# This data sb
#  is invalid and will be ignored
# This data gg
#  is invalid and will be ignored
# This data ll
#  is invalid and will be ignored
# This data df
#  is invalid and will be ignored
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.pyplot as plt
import numpy as np

file=open("cartype.txt","r")
types=['sporty','van','compact','large','midsize','small']
frequency=[0]*6
data=file.read().split('\n')
file.close()

for car_type in data:
    if car_type in types:
        i=types.index(car_type)
        frequency[i]+=1
        
colors=['skyblue','blue','purple','lightskyblue','blue','purple']
plt.pie(frequency, labels=types, colors=colors,autopct='%1.2f%%',
        explode = (0.025,0.025,0.025,0.025,0.025,0.025),shadow=False, startangle=80)
plt.axis('auto')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

file=open("cartype.txt","r")
types=['sporty','van','compact','large','midsize','small']
frequency=[0]*6
data=file.read().split('\n')
file.close()

for car_type in data:
    if car_type in types:
        i=types.index(car_type)
        frequency[i]+=1
        
colors=['skyblue','blue','purple','lightskyblue','blue','purple']
plt.pie(frequency, labels=types, colors=colors,autopct='%1.2f%%',explode = (0.025,0.025,0.025,0.025,0.025,0.025),shadow=False, startangle=80)
plt.axis('auto')
plt.show()
